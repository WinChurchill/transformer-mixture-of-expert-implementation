# %% [markdown]
# # Project 01 Reading Notebook Index
#
# These notebooks summarize the readings from `docs/project_01_combined_assignment_roadmap.md`. They are intentionally separated by day so each study session has a compact reading packet.
#
# Dates assume daily work from **2026-06-13** through **2026-06-19**.
#
# | Date | Notebook | Focus |
# | --- | --- | --- |
# | 2026-06-13 | `day_01_orientation_shapes_embeddings_loss.ipynb` | Transformer framing, embeddings, logits, loss, repo orientation |
# | 2026-06-14 | `day_02_causal_attention_manual_core.ipynb` | Scaled dot-product attention, causal masking, multi-head shapes |
# | 2026-06-15 | `day_03_modern_decoder_block.ipynb` | RoPE, RMSNorm, SwiGLU, modern decoder-block upgrade path |
# | 2026-06-16 | `day_04_training_loop_tiny_overfit.ipynb` | Batching, AdamW, eval, checkpointing, shifted targets |
# | 2026-06-17 | `day_05_generation_sampling_moe.ipynb` | Generation controls, top-k/top-p, MoE routing distinction |
# | 2026-06-18 | `day_06_kv_cache_prefill_decode.ipynb` | KV-cache shape contract, memory formula, cached correctness |
# | 2026-06-19 | `day_07_benchmark_report_portfolio_gate.ipynb` | Profiler, benchmark metrics, FlashAttention motivation, report gate |
#
# Source links are included in each notebook so you can go back to the original paper or docs after reading the summary.
